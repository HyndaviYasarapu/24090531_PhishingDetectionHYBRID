# %% [markdown]
# # The Intelligent Phishing Detection System
# ## Using Machine Learning, URL Features, and Web Content Analysis
#
# ---
#
# ###  Developed By: Hyndavi Yasarapu
# ###  ID: 24090531
# ### Course: MSc Advanced Computer Science
# ### Course Title: 7COM1039-0206-2025 - Advanced Computer Science Masters Project
#
# ---
#
# ### 📌 Project Overview
#
# This project presents an intelligent phishing detection system that combines:
#
# -  **Machine Learning (ML) Techniques**
# -  **URL-Based Feature Extraction**
# -  **Web Content Analysis**
# -  **Hybrid Detection Approach (Rule-Based + ML-Based)**
#
# The system is designed to accurately detect malicious phishing websites by analyzing structural URL patterns, extracting meaningful web content features, and applying trained machine learning models.
#
# ---
#
# ### 🎯 Objective
#
# To build a robust, scalable, and intelligent cybersecurity solution that improves phishing detection accuracy by integrating multiple analytical techniques.
#
# ---

# %% [markdown]
# ##  Importing Required Libraries and Project Modules
# In this section, we import all the necessary libraries and modules required to run the Intelligent Phishing Detection System.
# ###  Standard Python Libraries
# - **os** → Used for handling file paths and directory operations.
# - **sys** → Allows modification of the Python path to include project folders.
# - **warnings** → Used to suppress unnecessary warning messages for cleaner output.
#
# -- <small> **Author** hyndavi yasarapu <small> --

# %%
import os
import sys
import warnings
warnings.filterwarnings('ignore')

from src.data_preparation_hy import DataPreparation, create_sample_dataset
from src.feature_extraction_hy import extract_features_from_dataset

from config import DATA_DIR, MODELS_DIR, RESULTS_DIR
import pandas as pd

# %% [markdown]
# #### Directory SetUP
#
# This function creates the required project folders automatically if they don’t already exist.
#
# **DATA_DIR** → Where your dataset and processed features are stored
#
# **MODELS_DIR** → Where trained ML models are saved
#
# **RESULTS_DIR** → Where evaluation results and outputs are saved
#
# -- <small> **Author** hyndavi yasarapu <small> --

# %%
def setup_directories_hy():
    """Create necessary project directories"""
    for directory_hy in [DATA_DIR, MODELS_DIR, RESULTS_DIR]:
        os.makedirs(directory_hy, exist_ok=True)
    
    print("Project directories created/verified successfully.")

# %% [markdown]
# ## Step 1: Data Preparation
#
# 1. The dataset is loaded using the `DataPreparation` class.
# 2. The system tries to download the Kaggle dataset automatically (if configured).
# 3. If the dataset is not available, a sample dataset is created for demonstration.
# 4. Duplicate URLs are removed to avoid repeated data.
# 5. Missing values and invalid entries are cleaned from the dataset.
# 6. The cleaned dataset is prepared for the next step: Feature Extraction.
#
# -- <small> **Author** hyndavi yasarapu <small> --

# %%
# ============================================
# STEP 1: DATA PREPARATION
# ============================================

print("="*70)
print("STEP 1: DATA PREPARATION (KAGGLE DATASET)")
print("="*70)

# Data preparation variable is prep_hy

prep_hy = DataPreparation()

try:
    # Try loading Kaggle dataset
    sample_dataset_hy = prep_hy.load_raw_data(try_auto_download=True)
    sample_dataset_hy = prep_hy.clean_data(sample_dataset_hy)

except FileNotFoundError:
    print("\nDEMO MODE: Creating Sample Dataset")
    print("Kaggle dataset not found. Creating sample dataset...")

    sample_dataset_hy = create_sample_dataset(n_samples=3000)
    sample_dataset_hy = prep_hy.clean_data(sample_dataset_hy)

print("\nData Preparation Complete!")
print("Dataset shape:", sample_dataset_hy.shape)
sample_dataset_hy.head()
# Out:
# ...
# STEP 1: DATA PREPARATION (KAGGLE DATASET)
# ...
#
# Dataset not found at C:\Users\Pradeep Alvala\Documents\MastersProjectAndDoc\24090531_PhishingDetectionHYBRID\data\phishing_dataset_hyn.csv
#
# Attempting automatic download from Kaggle...
#
# Attempting to download Kaggle dataset: shashwatwork/web-page-phishing-detection-dataset
# Checking Kaggle API credentials...
# ✓ Kaggle package found
# ...
# Dataset URL: https://www.kaggle.com/datasets/shashwatwork/web-page-phishing-detection-dataset
# ✓ Dataset downloaded successfully!
# ✓ Renamed dataset_phishing.csv to phishing_dataset.csv
#
# ✓ Dataset ready at: C:\Users\Pradeep Alvala\Documents\MastersProjectAndDoc\24090531_PhishingDetectionHYBRID\data\phishing_dataset_hyn.csv
#
# Loading Kaggle dataset from C:\Users\Pradeep Alvala\Documents\MastersProjectAndDoc\24090531_PhishingDetectionHYBRID\data\phishing_dataset_hyn.csv...
# Initial dataset shape: (11430, 89)
# ...

# %% [markdown]
# ## Step 2: Feature Extraction
# This step focuses on extracting meaningful features from the dataset of URLs. Feature extraction is an important stage in the machine learning pipeline because it converts raw URL data into structured numerical attributes that can be used by the model for training and prediction.
# ### Process Overview
# Dataset Size Check
# The program checks the size of the dataset using len(sample_dataset_hy) to determine whether it is small or large.
# Feature Extraction for Small Datasets (≤ 500 URLs)
# If the dataset contains 500 or fewer URLs, the system extracts features from all URLs:
# 1. The function prep_hy.load_or_extract_features() is called to generate features.
# 2. The parameter force_extract=False ensures that if previously extracted features exist, they can be reused instead of recomputing them.
# Feature Extraction for Large Datasets (> 500 URLs)
# If the dataset is large, processing all URLs at once may be computationally expensive. Therefore:
# 1. The code selects only the first 500 URLs using sample_dataset_hy.head(500).
# Feature extraction is performed on this subset to allow quick experimentation and testing.
# ### Feature Extraction Function
# The method prep_hy.load_or_extract_features() performs the following tasks:
# 1. Loads previously saved features if available.
# 2. Otherwise extracts new features from each URL.
# 3. These features may include lexical, structural, and network-based characteristics relevant for phishing detection.
# ### Output Information
# After feature extraction is completed, the code prints:
# 1. The shape of the feature dataset (features_df_HY.shape), indicating the number of URLs and extracted features.
# 2. The list of feature column names, which represent the attributes used in the machine learning model.
#
# -- <small> **Author** hyndavi yasarapu <small> --

# %%
# ================================================================
# STEP 2: FEATURE EXTRACTION
# ================================================================
print("\n" + "="*70)
print("STEP 2: FEATURE EXTRACTION")
print("="*70)
    
# For sample/small datasets, extract features
# For large datasets, you may want to extract features in batches
    
if len(sample_dataset_hy) <= 500:
    print("\nExtracting features from URLs...")
    print("Note: This may take a few minutes for network-based features...")
    features_df_HY = prep_hy.load_or_extract_features(sample_dataset_hy, force_extract=False)
else:
    print("\nLarge dataset detected. Extracting features from first 500 URLs...")
    print("For full dataset, run feature extraction separately.")
    df_datasetHY_sample = sample_dataset_hy.head(3000)
    features_df_HY = prep_hy.load_or_extract_features(df_datasetHY_sample, force_extract=False)
    
print(f"\nFeature extraction complete!")
print(f"Features shape: {features_df_HY.shape}")
print(f"Features: {list(features_df_HY.columns)}")
# Out:
# ...
# STEP 2: FEATURE EXTRACTION
# ...
#
# Large dataset detected. Extracting features from first 500 URLs...
# For full dataset, run feature extraction separately.
#
# Extracting features from URLs...
# This may take a while depending on dataset size...
# Consider extracting features from a sample first for testing.
# Extracting features from URLs...
#   0%|          | 3/3000 [00:02<42:05,  1.19it/s]
# Error extracting content features from https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E7E497C050>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno 11001] getaddrinfo failed)"))
# ...

# %% [markdown]
# ## Step 3: Train–Test Split
# This step prepares the extracted features for machine learning by dividing the dataset into training and testing subsets. Splitting the dataset ensures that the model is trained on one portion of the data while its performance is evaluated on unseen data, which helps measure the model’s ability to generalize.
#
# ### Splitting the Dataset
# The function prep_hy.prepare_train_test_split(features_df_HY) is used to divide the dataset into four components:
# 1. X_train_hyn – Training feature set used to train the machine learning model.
# 2. X_test_hyn – Testing feature set used to evaluate the trained model.
# 3. y_train_hyn – Training labels representing the target variable (e.g., phishing or legitimate).
# 4. y_test_hyn – Testing labels used to validate model predictions.
# This separation prevents the model from learning patterns directly from the test data, ensuring a fair and unbiased evaluation.
# ### Feature Scaling
# After splitting the dataset, feature scaling is applied using the function prep_hy.scale_features(X_train_hyn, X_test_hyn).
# Feature scaling is necessary because machine learning algorithms perform better when numerical features are within a similar range. Without scaling, features with larger numerical values may dominate the learning process.
# The scaling process produces:
# 1. X_train_scaledhyn – Scaled training features used for model training.
# 2. X_test_scaledhyn – Scaled testing features used for model evaluation.
#
# -- <small> **Author** hyndavi yasarapu <small> --

# %%
# ================================================================
# STEP 3: TRAIN-TEST SPLIT
# ================================================================
print("\n" + "="*70)
print("STEP 3: TRAIN-TEST SPLIT")
print("="*70)
    
X_train_hyn, X_test_hyn, y_train_hyn, y_test_hyn = prep_hy.prepare_train_test_split(features_df_HY)
    
# Scale features for ML
X_train_scaledhyn, X_test_scaledhyn = prep_hy.scale_features(X_train_hyn, X_test_hyn)
# Out:
# ...
# STEP 3: TRAIN-TEST SPLIT
# ...
#
# Preparing train-test split...
# Training set: 400 samples
# Test set: 100 samples
#
# Training set class distribution:
# label
# 0    214
# 1    186
# Name: count, dtype: int64
#
# Test set class distribution:
# label
# 0    53
# 1    47
# Name: count, dtype: int64
#
# Saved train data to C:\Users\Pradeep Alvala\Documents\MastersProjectAndDoc\24090531_PhishingDetectionHYBRID\data\train_data_hyn.csv
# Saved test data to C:\Users\Pradeep Alvala\Documents\MastersProjectAndDoc\24090531_PhishingDetectionHYBRID\data\test_data_hyn.csv
#
# Scaling features...

# %% [markdown]
# ## Step 4: Rule-Based Phishing Detector
# In this step, a rule-based phishing detection model is implemented. Unlike machine learning models that learn patterns automatically from data, this approach uses predefined heuristic rules based on known phishing characteristics. These rules analyze different URL and webpage features to determine whether a website is likely to be phishing or legitimate.
# ### Key Implementation Steps
# 1. Importing the Rule-Based Detector
# The RuleBasedDetector class is imported from the src.rule_based_detector module. This class contains the logic required to define phishing detection rules, optimize thresholds, evaluate performance, and save the trained detector.
# 2. Initializing the Detector
#     rule_detector_class_hyn = RuleBasedDetector()
#     An instance of the RuleBasedDetector class is created. This object will manage rule definitions, threshold optimization, prediction, and evaluation.
# 3. Threshold Optimization
#     rule_detector_class_hyn.optimize_thresholds(X_train_hyn, y_train_hyn)
#     This step analyzes the training dataset to determine optimal threshold values for important URL features such as:
#     1. URL length
#     2. Number of subdomains
#     3. Number of dots in the URL
#     4. Number of hyphens
#     The system compares the feature distributions of legitimate and phishing URLs and computes threshold values that best separate the two categories. This improves the effectiveness of the heuristic rules.
# 4. Rule Definition
# After threshold optimization, a set of phishing detection rules is defined. Each rule checks a specific suspicious pattern in the URL or webpage features. Examples include:
#     1. Presence of an IP address in the URL
#     2. Excessive subdomains or dots
#     3. Use of URL shortening services
#     4. Presence of suspicious top-level domains (TLDs)
#     5. Absence of HTTPS security
#     6. Missing DNS records
#     7. Presence of login forms on suspicious pages
#     8. Excessive external links
#     9. Use of suspicious keywords
# Each rule is assigned a weight, representing its contribution to the overall phishing risk score.
# 5. Prediction Mechanism
# For each URL, the detector:
#     1. Evaluates all defined rules.
#     2. Adds the weights of triggered rules to compute a risk score.
#     3. Normalizes the score between 0 and 1.
# If the normalized risk score exceeds 30% of the maximum possible score, the URL is classified as phishing; otherwise, it is considered legitimate.
# 6. Model Evaluation
# rule_detector_metrics = rule_detector_class_hyn.evaluate(X_test_hyn, y_test_hyn)
# The detector is evaluated using the test dataset. Performance is measured using standard classification metrics:
#     1. Accuracy – Overall correctness of predictions
#     2. Precision – Proportion of predicted phishing URLs that are actually phishing
#     3. Recall – Ability to correctly identify phishing URLs
#     4. F1-Score – Harmonic mean of precision and recall
# Additionally, the evaluation reports rule trigger frequencies, indicating how often each rule contributed to phishing detection.
# 7. Saving the Detector
# rule_detector_class_hyn.save()
# The trained rule-based detector, including its rules and optimized thresholds, is saved using pickle serialization. This allows the model to be reused later without repeating the training process.
#
# The rule-based detector serves as a baseline phishing detection mechanism. It provides interpretable results and helps identify suspicious patterns before applying more advanced machine learning techniques. This hybrid approach improves system robustness by combining expert knowledge with data-driven methods.
#
# -- <small> **Author** hyndavi yasarapu <small> --

# %%
# ================================================================
# STEP 4: RULE-BASED DETECTOR
# ================================================================
from src.rule_based_detector_hy import RuleBasedDetector
print("\n" + "="*70)
print("STEP 4: RULE-BASED DETECTOR")
print("="*70)
    
rule_detector_class_hyn = RuleBasedDetector()
rule_detector_class_hyn.optimize_thresholds(X_train_hyn, y_train_hyn)
rule_detector_metrics = rule_detector_class_hyn.evaluate(X_test_hyn, y_test_hyn)
rule_detector_class_hyn.save()
# Out:
# ...
# STEP 4: RULE-BASED DETECTOR
# ...
# Optimizing rule-based thresholds...
#
# Optimized Thresholds:
#   url_length: 73.22235799041628
#   subdomain_count: 1.2440470244987336
#   dot_count: 2.7784181707187674
#   hyphen_count: 4.253224461687262
#
# ...
# RULE-BASED DETECTOR EVALUATION
# ...
#
# Accuracy:  0.5300
# Precision: 0.5000
# Recall:    0.0213
# F1-Score:  0.0408
#
# --------------------------------------------------
# Rule Trigger Frequency:
# --------------------------------------------------
# No HTTPS                      :    62 ( 62.0%)
# Excessive Dots                :    33 ( 33.0%)
# URL Shortening Service        :    22 ( 22.0%)
# URL Length                    :    16 ( 16.0%)
# No DNS Record                 :    13 ( 13.0%)
# Suspicious Keywords           :    13 ( 13.0%)
# Prefix/Suffix with Hyphen     :    11 ( 11.0%)
# Excessive Subdomains          :     8 (  8.0%)
# High External Links           :     8 (  8.0%)
# Excessive Hyphens             :     3 (  3.0%)
# ...

# %% [markdown]
# ## Step 5: Machine Learning Detector
# In this step, a machine learning-based phishing detection model is trained and evaluated. Unlike the rule-based approach, machine learning algorithms automatically learn patterns from the extracted features to classify URLs as phishing or legitimate. This allows the system to detect more complex patterns that may not be captured by manual rules.
# ### Key Implementation Steps
#
#
# #### Algorithm Selection
# Two options are presented:
# 1. Option 1: Train a single algorithm (Random Forest)
# 2. Option 2: Compare multiple machine learning algorithms
# For demonstration purposes, the system initially trains a Random Forest classifier, which is known for strong performance and robustness in classification problems.
#
# 1. Model Initialization
# ml_detector = MLDetector(algorithm='Random Forest')
# An instance of the MLDetector class is created, specifying Random Forest as the learning algorithm. This class manages model training, evaluation, and saving.
#
# 2. Model Training
#  ml_detector.train(X_train_scaled, y_train, use_grid_search=True)
#     The model is trained using the scaled training dataset.The parameter use_grid_search=True enables hyperparameter optimization, where the system tests different combinations of model parameters to identify the configuration that produces the best performance.
#
# 3. Model Evaluation
#  ml_metrics = ml_detector.evaluate(X_test_scaled, y_test)
#     After training, the model is evaluated using the test dataset to measure how well it performs on unseen data. The evaluation typically includes metrics such as:
#     1. Accuracy – Overall correctness of predictions
#     2. Precision – Proportion of predicted phishing URLs that are actually phishing
#     3. Recall – Ability to correctly identify phishing websites
#     4. F1-score – Balance between precision and recall
#
# 4. Model Saving
#  ml_detector.save()
#     The trained machine learning model is saved to disk so it can be reused later without retraining. This is important for deployment and reproducibility.
#
# #### Algorithm Comparison
# results, best_algo = compare_algorithms(X_train_scaled, X_test_scaled, y_train, y_test)
#     To identify the most effective model, multiple machine learning algorithms are compared using the same dataset. Each algorithm is trained and evaluated, and their performance metrics are recorded.
# ##### Selecting the Best Model
# ml_detector = results[best_algo]['detector']
#     The algorithm with the highest performance score is selected as the final machine learning detector. This ensures that the system uses the most accurate model for phishing detection.
# ##### Note:
#
# -- <small> The machine learning detector complements the rule-based detector by identifying complex phishing patterns that may not be captured by heuristic rules. Together, these approaches form a hybrid phishing detection system, combining expert knowledge with data-driven learning to improve overall detection accuracy and robustness. -- <small>
#
#   **Author** hyndavi yasarapu <small> --

# %%
# ================================================================
# STEP 5: MACHINE LEARNING DETECTOR
# ================================================================
print("\n" + "="*70)
print("STEP 5: MACHINE LEARNING DETECTOR")
print("="*70)
from src.ml_detector_hy import MLDetector  
from src.ml_detector_hy import compare_algorithms_all_hyn
print("\nOption 1: Train single best algorithm (Random Forest)")
print("Option 2: Compare multiple algorithms")

userinput = int(input("Select option 1 or Option 2"))


if userinput == 1:
    print("\nTraining Random Forest classifier...")
    ml_detector_hyn = MLDetector(algorithm='Random Forest')
    ml_detector_hyn.train(X_train_scaledhyn, y_train_hyn, use_grid_search=True)
    ml_metricshyn = ml_detector_hyn.evaluate(X_test_scaledhyn, y_test_hyn)
    ml_detector_hyn.save()
elif userinput == 2:
    print("\nComparing multiple algorithms...")
    ml_detector_hyn = MLDetector()
    resultshyn, best_algohyn = compare_algorithms_all_hyn(X_train_scaledhyn, X_test_scaledhyn, y_train_hyn, y_test_hyn)
    ml_detector_hyn = resultshyn[best_algohyn]['detector']
else:
    print("!!!!!!!!!!!!!!!!!! Check your Selection !!!!!!!!!!!!!!!!!!!!!!")
# Out:
# ...
# STEP 5: MACHINE LEARNING DETECTOR
# ...
#
# Option 1: Train single best algorithm (Random Forest)
# Option 2: Compare multiple algorithms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 12
#       9 print("\nOption 1: Train single best algorithm (Random Forest)")
#      10 print("Option 2: Compare multiple algorithms")
# ---> 12 userinput = int(input("Select option 1 or Option 2"))
#      15 if userinput == 1:
#      16     print("\nTraining Random Forest classifier...")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
# ...

# %% [markdown]
# ## Step 6: Hybrid Phishing Detection System
#
# This step implements a **hybrid phishing detection model** that combines the strengths of both the **rule-based detector** and the **machine learning detector**. The goal is to improve overall detection performance by leveraging both **expert-defined heuristics** and **data-driven learning**.
#
# ### Key Implementation Steps
#
# * **Step Initialization**
#   The code begins by printing a formatted header to indicate the start of the **Hybrid Detector** stage. This ensures clarity and structure in the execution flow.
# * **Validation Set Creation**
#
#   A **validation subset (20%)** is extracted from the training data. This dataset is used to:
#
#   * Tune hybrid model parameters
#   * Optimize combination strategies
#   * Avoid overfitting to the test set
#
# * **Hybrid Strategy Definition**
#
#   Three different hybrid strategies are evaluated:
#   * **Weighted Strategy**
#     Combines predictions from both models using optimized weights.
#   * **Voting Strategy**
#     Uses majority voting between rule-based and machine learning predictions.
#   * **Cascade Strategy**
#     Applies one model first (e.g., rule-based), then refines predictions using the second model.
#
# * **Strategy Evaluation Loop**
#   Each strategy is tested independently to determine its effectiveness.
#
# * **Hybrid Model Initialization**
#   A hybrid detector is created by combining:
#   * The **rule-based detector**
#   * The **machine learning detector**
#
# * **Weight Optimization (for Weighted Strategy)**
#   For the weighted approach, the system learns the **optimal contribution (weights)** of each model using the validation dataset.
#
# * **Model Evaluation**
#   Each hybrid strategy is evaluated on the **test dataset** using performance metrics such as:
#
#   * Accuracy
#   * Precision
#   * Recall
#   * F1-score
#
#   The `show_comparison=True` option allows comparison between hybrid and individual models.
#
# * **Best Strategy Selection**
#   The system selects the **best-performing hybrid strategy** based on the **F1-score**, which balances precision and recall—an important metric for phishing detection.
#
# * **Final Model Selection**
#   The hybrid model with the highest performance is stored as the final detector.
#
# * **Saving the Hybrid Model**`
#   The best hybrid model is saved for future use, enabling deployment without retraining.
#
# ### Note
#
# The hybrid detector represents the **final and most advanced stage** of the phishing detection system. By combining rule-based logic with machine learning predictions, it achieves:
#
# * Improved detection accuracy
# * Better handling of complex phishing patterns
# * Increased robustness and reliability
#
# This approach demonstrates a **comprehensive cybersecurity solution**, making it highly suitable for real-world phishing detection systems and strengthening the overall contribution of the project.
#
# -- <small> **Author** hyndavi yasarapu <small> --

# %%
# ================================================================
# STEP 6: HYBRID DETECTOR
# ================================================================
print("\n" + "="*70)
print("STEP 6: HYBRID DETECTOR")
print("="*70)
from src.hybrid_detector_hy import HybridDetector 
from src.ml_detector_hy import MLDetector
from src.rule_based_detector_hy import RuleBasedDetector
rule_based_detector_hy = RuleBasedDetector()
ml_detector_hy = MLDetector(algorithm='Random Forest')
ml_detector_hy.train(X_train_scaledhyn, y_train_hyn, use_grid_search=True)
# Create validation set from training data for weight optimization
val_size_hyn = int(len(X_train_hyn) * 0.2)
X_val_hyn = X_train_hyn.iloc[-val_size_hyn:]
y_val_hyn = y_train_hyn.iloc[-val_size_hyn:]
X_val_scaledhyn = X_train_scaledhyn.iloc[-val_size_hyn:]
    
# Try different strategies
strategies = ['weighted', 'voting', 'cascade']
best_strategy = None
best_f1 = 0
best_hybrid_hyn = None
    
for strategy in strategies:
    print(f"\n{'='*70}")
    print(f"Testing Hybrid Strategy: {strategy.upper()}")
    print(f"{'='*70}")
        
    hybrid = HybridDetector(rule_based_detector_hy, ml_detector_hy, strategy=strategy)
        
    if strategy == 'weighted':
        hybrid.optimize_weights(X_val_scaledhyn, y_val_hyn)
        
    metrics = hybrid.evaluate(X_test_scaledhyn, y_test_hyn, show_comparison=True)
        
    if metrics['f1_score'] > best_f1:
        best_f1 = metrics['f1_score']
        best_strategy = strategy
        best_hybrid_hyn = hybrid
    
print(f"\n{'='*70}")
print(f"BEST HYBRID STRATEGY: {best_strategy.upper()}")
print(f"F1-Score: {best_f1:.4f}")
print(f"{'='*70}")
    
# Save best hybrid detector
best_hybrid_hyn.save()

# %% [markdown]
# ## Step 7: Detailed Prediction Analysis
#
# * This step performs an **in-depth evaluation** of the best-performing hybrid model.
# * The method `analyze_predictions()` is invoked on the **selected hybrid detector**.
# * It evaluates a subset of the test dataset (`n_samples=5`) to provide **interpretable insights**.
# * For each sample, the model outputs:
#
#   * **True label** (actual classification: phishing or legitimate)
#   * **Predicted label** (model’s decision)
#   * **Correctness of prediction**
#   * **Combined score** from hybrid strategy
#   * **Individual contributions**:
#
#     * Rule-based score
#     * Machine learning probability score
#   * **Confidence level** of prediction
# * This step is critical for:
#
#   * Understanding **model behaviour**
#   * Identifying **misclassifications**
#   * Demonstrating **explainability** of the hybrid approach
#
# --------------------------------------------------------------------------------------------------------------------
#
# ## Step 8: Final Summary
#
# * This step provides a **consolidated overview** of the entire phishing detection pipeline.
# * It confirms that all models have been:
#
#   * Successfully **trained**
#   * Properly **evaluated**
#
# ### Key Outputs:
#
# * Displays **F1-scores** of all models:
#
#   * Rule-Based Detector
#   * Machine Learning Detector
#   * Hybrid Detector
# * Enables **performance comparison** across different approaches.
#
# ### Model & Results Storage:
#
# * Specifies the directory where trained models are saved (`MODELS_DIR`)
# * Specifies the directory where evaluation results and plots are stored (`RESULTS_DIR`)
#
# ### Completion Message:
#
# * Confirms **successful execution** of the entire pipeline
#
# ---
#
# ## Returned Output
#
# * The pipeline returns a structured dictionary containing:
#
#   * Trained **Rule-Based Detector**
#   * Trained **Machine Learning Detector**
#   * Best-performing **Hybrid Detector**
#   * Performance **metrics** for all models:
#
#     * Rule-based metrics
#     * ML-based metrics
#     * Hybrid F1-score

# %%
# ================================================================
# STEP 7: DETAILED ANALYSIS
# ================================================================
print("\n" + "="*70)
print("STEP 7: DETAILED PREDICTION ANALYSIS")
print("="*70)
    
best_hybrid_hyn.analyze_predictions(X_test_scaledhyn, y_test_hyn, n_samples=5)
    
# ================================================================
# STEP 8: FINAL SUMMARY
# ================================================================
print("\n" + "="*70)
print("FINAL SUMMARY")
print("="*70)
    
print("\nAll detection systems have been trained and evaluated!")
print(f"\nResults Summary:")
print(f"  Rule-Based Detector F1-Score:  {rule_detector_metrics['f1_score']:.4f}")
print(f"  ML Detector F1-Score:          {ml_metricshyn['f1_score']:.4f}")
print(f"  Hybrid Detector F1-Score:      {best_f1:.4f}")
    
print(f"\nModels saved in: {MODELS_DIR}")
print(f"Results saved in: {RESULTS_DIR}")
    
print("\n" + "="*70)
print("Pipeline execution completed successfully!")
print("="*70)

# %% [markdown]
# #
